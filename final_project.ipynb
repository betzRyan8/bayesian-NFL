# %%
import pandas as pd

df_nfl = pd.read_csv('nfl_merged.csv')

df_nfl.head()
# Out:
#   schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0      9/2/1966             1966             1             False
# 1      9/3/1966             1966             1             False
# 2      9/4/1966             1966             1             False
# 3      9/9/1966             1966             2             False
# 4     9/10/1966             1966             1             False
#
#             team_home  score_home  score_away        team_away  \
# 0      miami dolphins        14.0        23.0  oakland raiders
# 1      houston oilers        45.0         7.0   denver broncos
# 2  san diego chargers        27.0         7.0    buffalo bills
# 3      miami dolphins        14.0        19.0    new york jets
# 4   green bay packers        24.0         3.0  baltimore colts
#
#   team_favorite_id  spread_favorite  ... weather_temperature weather_wind_mph  \
# 0              NaN              NaN  ...                83.0              6.0
# 1              NaN              NaN  ...                81.0              7.0
# 2              NaN              NaN  ...                70.0              7.0
# 3              NaN              NaN  ...                82.0             11.0
# 4              NaN              NaN  ...                64.0              8.0
#
#    weather_humidity  weather_detail  team_id_home  home_conference  \
# 0              71.0             NaN           MIA              AFC
# 1              70.0             NaN           TEN              AFC
# 2              82.0             NaN           LAC              AFC
# 3              78.0             NaN           MIA              AFC
# 4              62.0             NaN            GB              NFC
#
#   home_division team_id_away away_conference away_division
# 0      AFC East          LVR             AFC      AFC West
# 1           NaN          DEN             AFC      AFC West
# 2      AFC West          BUF             AFC      AFC East
# 3      AFC East          NYJ             NFC      AFC East
# 4     NFC North          IND             AFC           NaN
#
# [5 rows x 23 columns]

# %%
#drop games with no betting lines
df_nfl = df_nfl.dropna(subset=['team_favorite_id', 'spread_favorite', 'over_under_line'])

#clean columns
df_nfl['over_under_line'] = df_nfl['over_under_line'].astype(str).str.strip()

df_nfl['over_under_line'] = pd.to_numeric(df_nfl['over_under_line'], errors='coerce')

df_nfl.head()
# Out:
#      schedule_date  schedule_season schedule_week  schedule_playoff  \
# 350      1/14/1968             1967     Superbowl              True
# 538      1/12/1969             1968     Superbowl              True
# 727      1/11/1970             1969     Superbowl              True
# 916      1/17/1971             1970     Superbowl              True
# 1105     1/16/1972             1971     Superbowl              True
#
#                team_home  score_home  score_away          team_away  \
# 350    green bay packers        33.0        14.0    oakland raiders
# 538      baltimore colts         7.0        16.0      new york jets
# 727   kansas city chiefs        23.0         7.0  minnesota vikings
# 916      baltimore colts        16.0        13.0     dallas cowboys
# 1105      dallas cowboys        24.0         3.0     miami dolphins
#
#      team_favorite_id  spread_favorite  ...  weather_temperature  \
# 350                GB            -13.5  ...                 60.0
# 538               IND            -18.0  ...                 66.0
# 727               MIN            -12.0  ...                 55.0
# 916               IND             -2.5  ...                 59.0
# 1105              DAL             -6.0  ...                 34.0
#
#      weather_wind_mph  weather_humidity  weather_detail  team_id_home  \
# 350              12.0              74.0             NaN            GB
# 538              12.0              80.0            rain           IND
# 727              14.0              84.0            rain            KC
# 916              11.0              60.0             NaN           IND
# 1105             18.0              40.0             NaN           DAL
#
#       home_conference home_division team_id_away away_conference away_division
# 350               NFC     NFC North          LVR             AFC      AFC West
# 538               AFC           NaN          NYJ             NFC      AFC East
# 727               AFC      AFC West          MIN             NFC     NFC North
# 916               AFC           NaN          DAL             NFC      NFC East
# 1105              NFC      NFC East          MIA             AFC      AFC East
#
# [5 rows x 23 columns]

# %%
#create probability columns

#win probability
df_nfl['home_win'] = (df_nfl['score_home'] > df_nfl['score_away']).astype(int)

#spread cover probability
df_nfl['score_diff'] = df_nfl['score_home'] - df_nfl['score_away']

df_nfl['is_home_favorite'] = (df_nfl['team_favorite_id'] == df_nfl['team_id_home']).astype(int)

df_nfl['favorite_score_diff'] = df_nfl['score_diff'].where(
    df_nfl['is_home_favorite'] == 1,
    -df_nfl['score_diff']
)

df_nfl['cover_margin'] = df_nfl['favorite_score_diff'] + df_nfl['spread_favorite']

df_nfl['favorite_cover'] = (df_nfl['cover_margin'] > 0).astype(int)

#over/under probability
df_nfl['total_score'] = df_nfl['score_home'] + df_nfl['score_away']

df_nfl['over_result'] = (df_nfl['total_score'] > df_nfl['over_under_line']).astype(int)

df_nfl['over_under_margin'] = df_nfl['total_score'] - df_nfl['over_under_line']

df_nfl.head()
# Out:
#      schedule_date  schedule_season schedule_week  schedule_playoff  \
# 350      1/14/1968             1967     Superbowl              True
# 538      1/12/1969             1968     Superbowl              True
# 727      1/11/1970             1969     Superbowl              True
# 916      1/17/1971             1970     Superbowl              True
# 1105     1/16/1972             1971     Superbowl              True
#
#                team_home  score_home  score_away          team_away  \
# 350    green bay packers        33.0        14.0    oakland raiders
# 538      baltimore colts         7.0        16.0      new york jets
# 727   kansas city chiefs        23.0         7.0  minnesota vikings
# 916      baltimore colts        16.0        13.0     dallas cowboys
# 1105      dallas cowboys        24.0         3.0     miami dolphins
#
#      team_favorite_id  spread_favorite  ...  away_division home_win  \
# 350                GB            -13.5  ...       AFC West        1
# 538               IND            -18.0  ...       AFC East        0
# 727               MIN            -12.0  ...      NFC North        1
# 916               IND             -2.5  ...       NFC East        1
# 1105              DAL             -6.0  ...       AFC East        1
#
#       score_diff  is_home_favorite  favorite_score_diff  cover_margin  \
# 350         19.0                 1                 19.0           5.5
# 538         -9.0                 1                 -9.0         -27.0
# 727         16.0                 0                -16.0         -28.0
# 916          3.0                 1                  3.0           0.5
# 1105        21.0                 1                 21.0          15.0
#
#      favorite_cover total_score over_result over_under_margin
# 350               1        47.0           1               4.0
# 538               0        23.0           0             -17.0
# 727               0        30.0           0              -9.0
# 916               1        29.0           0              -7.0
# 1105              1        27.0           0              -7.0
#
# [5 rows x 32 columns]

# %%
df_nfl.to_csv('nfl_final.csv', index=False)
